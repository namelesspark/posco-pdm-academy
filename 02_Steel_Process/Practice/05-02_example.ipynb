# %%
import pandas as pd
import matplotlib.pyplot as plt

file_path = '../Data/05-02_라벨설계_센서데이터.csv'
data = pd.read_csv(file_path)
data['timestamp'] = pd.to_datetime(data['timestamp'])

data.head()
# Out:
#             timestamp  vibration_rms  bearing_temp  motor_current  load_pct  \
# 0 2026-07-08 00:00:00          2.148         48.58          31.85      72.6
# 1 2026-07-08 01:00:00          2.098         48.08          30.90      70.2
# 2 2026-07-08 02:00:00          2.203         48.92          32.39      76.0
# 3 2026-07-08 03:00:00          2.384         48.86          32.06      77.8
# 4 2026-07-08 04:00:00          2.239         49.21          32.72      79.7
#
#    run_state post_repair_grade  hours_to_failure
# 0          1                 A             179.3
# 1          1                 A             178.3
# 2          1                 A             177.3
# 3          1                 A             176.3
# 4          1                 A             175.3

# %%
plt.rcParams['font.family'] = 'Malgun Gothic'
plt.rcParams['axes.unicode_minus'] = False

plt.figure(figsize=(12, 5))
plt.plot(data['timestamp'], data['vibration_rms'], marker='o', markersize=3)

plt.title('MTR01 vibration_rms 변화')
plt.xlabel('timestamp')
plt.ylabel('vibration_rms')
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
print('진동 패턴은 고장 시각보다 약 96시간 전쯤부터 달라지는 것 같다.')
print('고장 직전 24시간은 그 전보다 진동이 더 크게 올라가고 이미 고장이 많이 진행된 상태처럼 보인다.')
# Out:
# 진동 패턴은 고장 시각보다 약 96시간 전쯤부터 달라지는 것 같다.
# 고장 직전 24시간은 그 전보다 진동이 더 크게 올라가고 이미 고장이 많이 진행된 상태처럼 보인다.
